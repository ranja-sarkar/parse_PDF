# %%
#%matplotlib notebook

#%matplotlib inline

from PIL import Image
from scipy import *
from pylab import *

im = array(Image.open('C:/Users/Ranja.Sarkar/t.jpeg'))

hh = im.shape[0]
ww = im.shape[1]

#imshow(im)    

Col = array([255, 0, 0])
#bnd = 30

ymax_lin = log10(0.5)
ymin_lin = log10(2e-4)

yax = linspace(ymax_lin, ymin_lin, hh)
xax = linspace(1, 14, ww)

for i in range(hh):
    for j in range(ww):
        im[i,j,:] = 255 * (any(im[i,j,:] > Col) or any(im[i,j,:] < Col))
#        im[i,j,:] = 255*(any(im[i,j,:] > Col + bnd) or any(im[i,j,:] < Col - bnd))

mapim = abs(im[:,:,0]/255-1).astype(bool)

yval = array([average(yax[mapim[:,t]]) for t in range(ww)])

#print(xax, yval)
# Out:
# C:\Users\Ranja.Sarkar\AppData\Local\Continuum\anaconda2\lib\site-packages\numpy\lib\function_base.py:392: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Users\Ranja.Sarkar\AppData\Local\Continuum\anaconda2\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
print(im.shape, hh, ww, len(xax), len(yval))
# Out:
# (465, 666, 3) 465 666 666 666

# %%
# %matplotlib notebook

plot(xax, yval)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
"""
col = array([255,0,0])
bnd = 30

col + bnd, col - bnd

"""
#(array([285,  30,  30]), array([225, -30, -30]))
# Out:
# (array([285,  30,  30]), array([225, -30, -30]))

# %%
import pandas as pd

df = pd.DataFrame(columns = ['x-value', 'y-value'])

for i in range(0, 666):
    df = df.append({'x-value':xax.round(2)[i],'y-value': yval.round(2)[i]}, ignore_index = True)

#df
